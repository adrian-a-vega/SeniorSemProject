# %% [markdown]
# [Source: Kaggle "Spanish to English Translation" dataset](https://www.kaggle.com/code/sharanharsoor/spanish-to-english-translation/notebook#Create-source-and-target-sequences-using-tokenize())
#
# Lines 3 to 29 use code from source. These lines import the datset and process the data to be used by models.

# %%
import os, io
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import tensorflow as tf
import warnings
import pathlib
from itertools import islice

# %%
tf.get_logger().setLevel('ERROR')
pwd = pathlib.Path.cwd()

# %%
# lines 9 to 11. Overview: Download and visualize data from Keggle(SHRAN HARSOOR)

# %%
zipFile = tf.keras.utils.get_file(
    'spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip',
    extract=True)

#filePath = os.path.dirname(zipFile)+"/spa-eng/spa.txt"
filePath = "/root/.keras/datasets/spa-eng_extracted/spa-eng/spa.txt"
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# 2638744/2638744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
! head -10 /root/.keras/datasets/spa-eng_extracted/spa-eng/spa.txt
# Out:
# Go.	Ve.
# Go.	Vete.
# Go.	Vaya.
# Go.	Váyase.
# Hi.	Hola.
# Run!	¡Corre!
# Run.	Corred.
# Who?	¿Quién?
# Fire!	¡Fuego!
# Fire!	¡Incendio!

# %%
def loadData(path, size=20000):
  #text = io.open(filePath, encoding='UTF-8').read()
  #lines = text.splitlines()
  #pairs = [line.split('\t') for line in lines]
  with io.open(path, 'r', encoding='utf-8', newline='') as f:
    lines = [line.rstrip('\n') for line in islice(f, size)]
  pairs = [line.split('\t') for line in lines if '\t' in line]
  sp = np.array([source for target, source in pairs])
  en = np.array([target for target, source in pairs])
  return sp, en

# %%
spSentences , enSentences = loadData(filePath)
print("sp sentences:", spSentences[42])
print("en sentences:", enSentences[42])
# Out:
# sp sentences: Yo lo sé.
# en sentences: I know.

# %%
df = pd.DataFrame(zip(spSentences, enSentences), columns=['sp', 'en'])
df
# Out:
#                                                        sp  \
# 0                                                     Ve.
# 1                                                   Vete.
# 2                                                   Vaya.
# 3                                                 Váyase.
# 4                                                   Hola.
# ...                                                   ...
# 118959  Hay cuatro causas principales de muertes relac...
# 118960  Hay madres y padres que se quedan despiertos d...
# 118961  Una huella de carbono es la cantidad de contam...
# 118962  Como suele haber varias páginas web sobre cual...
# 118963  Si quieres sonar como un hablante nativo, debe...
#
#                                                        en
# 0                                                     Go.
# 1                                                     Go.
# 2                                                     Go.
# 3                                                     Go.
# 4                                                     Hi.
# ...                                                   ...
# 118959  There are four main causes of alcohol-related ...
# 118960  There are mothers and fathers who will lie awa...
# 118961  A carbon footprint is the amount of carbon dio...
# 118962  Since there are usually multiple websites on a...
# 118963  If you want to sound like a native speaker, yo...
#
# [118964 rows x 2 columns]

# %%
# The following lines process the data by standardization anf tokenize.

# %%
import re, itertools
from collections import Counter
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# %%
import unicodedata

def unicode_to_ascii(s):
    normalized = unicodedata.normalize('NFD', s)
    return ''.join(c for c in normalized if unicodedata.category(c) != 'Mn')

def preprocess_text(text):
  text = unicode_to_ascii(text.lower().strip())
  text = re.sub(r"[^a-zA-Z?.!,¿]+", " ", text)
  text = re.sub(r"([?.!,¿])", r" \1 ", text)
  text = re.sub(r'[" "]+', " ", text)
  text = text.rstrip().strip()

  return text

# %%
print('Original sentence:',spSentences[42])
prc_sp_sentences = [preprocess_text(w) for w in spSentences]
prc_en_sentences = [preprocess_text(w) for w in enSentences]
print('Preprocessed sentence:',prc_sp_sentences[42])
# Out:
# Original sentence: Yo lo sé.
# Preprocessed sentence: yo lo se .

# %%
# the following lines will split the datasets into a train and test datasets.
# train data is used to "train" the model and test data is used to eval model.
spSentencesTrain, spSentencesVal, enSentencesTrain, enSentencesVal = train_test_split(prc_sp_sentences, prc_en_sentences, shuffle=False, test_size=0.2)
print(len(spSentencesTrain), len(spSentencesVal), len(enSentencesTrain), len(enSentencesVal))
# Out:
# 95171 23793 95171 23793

# %%
print(spSentencesTrain[1])
print(spSentencesVal[1])
print(enSentencesTrain[1])
print(enSentencesVal[1])
# Out:
# vete .
# te lo dije , pero no hiciste caso .
# go .
# i told you , but you didn t pay attention .

# %%
#defieneing the hyperparameters that will used within the models

# bufferSire -- bufffer size for the training data
bufferSize = len(spSentencesTrain)
# valBufferSize -- buffer size for the validatation data
valBufferSize = len(spSentencesVal)
# BATCHSIZE -- batch size for the training data
BATCHSIZE = 100
# embeddingDim -- embedding dimension for the input data
embeddingDim = 128
# units -- number of units in. the RNN used for model
units = 1024
# stepsPerEpoch -- number of steps to take each epoch of training
stepsPerEpoch = bufferSize
# valStepsPerEpoch -- validation steps to take during each epoch of training
valStepsPerEpoch = valBufferSize

# %%
trainDatasetUnbatched = tf.data.Dataset.from_tensor_slices((spSentencesTrain, enSentencesTrain))
trainDataset = trainDatasetUnbatched.shuffle(buffer_size=bufferSize).batch(BATCHSIZE)
valDatasetUnbatched = tf.data.Dataset.from_tensor_slices((spSentencesVal, enSentencesVal))
valDataset = valDatasetUnbatched.batch(BATCHSIZE)

# %%
##train_unbatched = trainDataset.unbatch()
train_en = trainDatasetUnbatched.map(lambda sp, en: en)
train_sp = trainDatasetUnbatched.map(lambda sp, en: sp)

# %%
from tensorflow_text.tools.wordpiece_vocab import bert_vocab_from_dataset as bert_vocab

# %%
import logging
import time
import tensorflow_datasets as tfds
import tensorflow_text as text

# %%
bert_tokenizer_params=dict(lower_case=True)
reserved_tokens=["[PAD]", "[UNK]", "[START]", "[END]"]

bert_vocab_args = dict(
    # The target vocabulary size
    vocab_size = 8000,
    # Reserved tokens that must be included in the vocabulary
    reserved_tokens=reserved_tokens,
    # Arguments for `text.BertTokenizer`
    bert_tokenizer_params=bert_tokenizer_params,
    # Arguments for `wordpiece_vocab.wordpiece_tokenizer_learner_lib.learn`
    learn_params={},
)

# %%
# %%time
sp_vocab = bert_vocab.bert_vocab_from_dataset(
    train_sp.batch(1000).prefetch(2),
    **bert_vocab_args
)
# Out:
# CPU times: user 48.7 s, sys: 403 ms, total: 49.1 s
# Wall time: 48.2 s

# %%
print(sp_vocab[:10])
print(sp_vocab[100:110])
print(sp_vocab[1000:1010])
print(sp_vocab[-10:])
# Out:
# ['[PAD]', '[UNK]', '[START]', '[END]', '!', ',', '.', '?', 'a', 'b']
# ['puede', 'tomas', 'tan', 'mucho', '##mos', 'tiempo', 'era', 'nos', 'cuando', 'ahora']
# ['verlo', 'vuelve', '##ido', '##lar', '##las', '##tado', 'asiento', 'caballo', 'escribio', 'espere']
# ['##,', '##.', '##?', '##b', '##f', '##j', '##q', '##v', '##x', '##¿']

# %%
def write_vocab_file(filepath, vocab):
  with open(filepath, 'w') as f:
    for token in vocab:
      print(token, file=f)

# %%
write_vocab_file('sp_vocab.txt', sp_vocab)

# %%
# %%time
en_vocab = bert_vocab.bert_vocab_from_dataset(
    train_en.batch(1000).prefetch(2),
    **bert_vocab_args
)
# Out:
# CPU times: user 24.5 s, sys: 387 ms, total: 24.9 s
# Wall time: 24.5 s

# %%
print(en_vocab[:10])
print(en_vocab[100:110])
print(en_vocab[1000:1010])
print(en_vocab[-10:])
# Out:
# ['[PAD]', '[UNK]', '[START]', '[END]', '!', ',', '.', '?', 'a', 'b']
# ['where', 'good', 'out', 'see', 'who', 'doesn', 'from', 'going', 'one', 'were']
# ['winter', '##ible', 'carry', 'charge', 'eight', 'grandfather', 'piece', 'shop', 'smell', 'solve']
# ['wings', 'yard', '##!', '##,', '##.', '##?', '##j', '##q', '##v', '##z']

# %%
write_vocab_file('en_vocab.txt', en_vocab)

# %%
ls *.txt
# Out:
# en_vocab.txt  sp_vocab.txt

# %%
sp_tokenizer = text.BertTokenizer('sp_vocab.txt', **bert_tokenizer_params)
en_tokenizer = text.BertTokenizer('en_vocab.txt', **bert_tokenizer_params)

# %%
for sp_examples, en_examples in trainDataset.take(1):
  for ex in en_examples:
    print(ex.numpy())
# Out:
# b'who does that belong to ?'
# b'warn tom .'
# b'i just wanted to see you .'
# b'the plans were discarded .'
# b'all the students come from the us .'
# b'since i was sick , i didn t go .'
# b'you have my word .'
# b'my husband always reads in bed .'
# b'all the students were there .'
# b'my heart was filled with happiness .'
# b'no one speaks this language anymore .'
# b'i walk in the forest every day .'
# b'you don t need to work today .'
# b'i know it s an experiment .'
# b'we want our money .'
# b'this room doesn t get much sun .'
# b'no one will believe you .'
# b'i m not telling you .'
# b'that s what you all say .'
# b'i have a bad pain in my back .'
# b'i have a special surprise for you .'
# b'i screamed .'
# b'tell me what you want for christmas .'
# b'half of these are mine .'
# b'we re in love .'
# b'it is wrong to steal money .'
# b'no one knows why .'
# b'i recommend maui .'
# b'thanks for your cooperation .'
# b'just do what i tell you .'
# b'his smug behavior is offensive .'
# b'don t point your gun at me .'
# b'tom hugged mary tightly .'
# b'he likes singing and dancing .'
# b'i need my pills .'
# b'we watch tv together .'
# b'is it there ?'
# b'i can keep a secret .'
# b'i ve always wanted to meet you .'
# b'look ! there s a bird in that tree .'
# b'the engine is purring .'
# b'i just can t forget about you .'
# b'i could just refuse to help tom .'
# b'tom liked australia .'
# b'tom can t think of a better plan .'
# b'tom wanted to stop and think .'
# b'nobody does that anymore .'
# b'even tom was baffled .'
# b'the air conditioner is out of order .'
# b'look at that dog .'
# b'have you seen my camera ?'
# b'tom closed the door and locked it .'
# b'i tried to persuade tom to come home .'
# b'tom walked across the street .'
# b'who teaches you french ?'
# b'we re feeling confident .'
# b'do come in !'
# b'this is delicious .'
# b'tom can t play tennis .'
# b'do you know anything about tom ?'
# b'tom seems incompetent .'
# b'i hope you aren t alone .'
# b'the problem is difficult to solve .'
# b'tom doesn t trust a thing mary says .'
# b'can you play the violin ?'
# b'he gave in .'
# b'he cut down a cherry tree .'
# b'perhaps the book will prove useful .'
# b'i have trouble talking about my feelings .'
# b'tom waved to mary .'
# b'i never drink .'
# b'let s wait for another minutes .'
# b'the early bird catches the worm .'
# b'you seem resourceful .'
# b'montgomery was where it all began .'
# b'he s not perfect .'
# b'jeans take forever to dry .'
# b'let s move on .'
# b'he can swim very fast .'
# b'a nod is a sign of agreement .'
# b'what time did that take place ?'
# b'tom has a private jet .'
# b'tom sat on a stool in the corner .'
# b'tom wanted to meet you .'
# b'this is hers .'
# b'she lives a few blocks away from here .'
# b'the noise awoke me from my sleep .'
# b'tom wants mary s opinion .'
# b'burglars broke into his house .'
# b'i m really proud of this .'
# b'he wants a watch just like yours .'
# b'have you ever tried scuba diving ?'
# b'i didn t feel like going .'
# b'how about adding a touch of pepper ?'
# b'please tell me how to get to the beach .'
# b'a blood transfusion is necessary .'
# b'how is the investigation s going ?'
# b'everything went black .'
# b'my heart was filled with happiness .'
# b'may i eat this cake ?'

# %%
token_batch = en_tokenizer.tokenize(en_examples)
token_batch = token_batch.merge_dims(-2, -1)

for ex in token_batch.to_list():
  print(ex)
# Out:
# [104, 143, 43, 1528, 35, 7]
# [1639, 37, 6]
# [16, 111, 203, 35, 103, 34, 6]
# [36, 1036, 109, 11, 1564, 2593, 1260, 121, 6]
# [83, 36, 596, 93, 106, 36, 120, 6]
# [737, 16, 48, 427, 5, 16, 85, 27, 71, 6]
# [34, 47, 46, 456, 6]
# [46, 801, 171, 2238, 41, 275, 6]
# [83, 36, 596, 109, 73, 6]
# [46, 698, 48, 1243, 67, 1540, 6]
# [98, 108, 554, 45, 721, 405, 6]
# [16, 392, 41, 36, 1914, 191, 139, 6]
# [34, 53, 27, 99, 35, 130, 140, 6]
# [16, 65, 40, 26, 96, 2804, 6]
# [50, 58, 167, 135, 6]
# [45, 156, 105, 27, 90, 132, 868, 6]
# [98, 108, 81, 237, 34, 6]
# [16, 20, 64, 1018, 34, 6]
# [43, 26, 52, 34, 83, 160, 6]
# [16, 47, 8, 270, 636, 41, 46, 137, 6]
# [16, 47, 8, 1314, 964, 56, 34, 6]
# [16, 2447, 6]
# [119, 44, 52, 34, 58, 56, 749, 6]
# [773, 49, 213, 54, 327, 6]
# [50, 72, 41, 158, 6]
# [40, 38, 253, 35, 2021, 135, 6]
# [98, 108, 249, 95, 6]
# [16, 1864, 20, 407, 1525, 870, 6]
# [644, 56, 57, 10, 3149, 2764, 782, 6]
# [111, 42, 52, 16, 119, 34, 6]
# [60, 26, 970, 1788, 1527, 38, 196, 2900, 688, 6]
# [53, 27, 927, 57, 934, 68, 44, 6]
# [37, 2321, 59, 1558, 229, 6]
# [39, 238, 724, 82, 1224, 6]
# [16, 99, 46, 3275, 6]
# [50, 286, 342, 388, 6]
# [38, 40, 73, 7]
# [16, 55, 226, 8, 553, 6]
# [16, 86, 171, 203, 35, 387, 34, 6]
# [166, 4, 73, 26, 8, 861, 41, 43, 578, 6]
# [36, 2211, 38, 23, 1837, 1524, 6]
# [16, 111, 55, 27, 472, 89, 34, 6]
# [16, 148, 111, 2151, 35, 114, 37, 6]
# [37, 875, 494, 6]
# [37, 55, 27, 88, 49, 8, 216, 363, 6]
# [37, 203, 35, 206, 82, 88, 6]
# [328, 143, 43, 405, 6]
# [390, 37, 48, 1656, 6]
# [36, 794, 1703, 231, 38, 102, 49, 841, 6]
# [166, 68, 43, 178, 6]
# [47, 34, 296, 46, 523, 7]
# [37, 814, 36, 240, 82, 1305, 40, 6]
# [16, 423, 35, 2434, 37, 35, 93, 129, 6]
# [37, 763, 1020, 36, 672, 6]
# [104, 1598, 34, 149, 7]
# [50, 72, 838, 2790, 6]
# [42, 93, 41, 4]
# [45, 38, 1140, 6]
# [37, 55, 27, 208, 434, 6]
# [42, 34, 65, 155, 89, 37, 7]
# [37, 318, 41, 2594, 970, 2765, 1521, 6]
# [16, 272, 34, 343, 27, 243, 6]
# [36, 251, 38, 501, 35, 1009, 6]
# [37, 105, 27, 508, 8, 341, 59, 441, 6]
# [55, 34, 208, 36, 2099, 7]
# [39, 232, 41, 6]
# [39, 565, 198, 8, 10, 1828, 728, 578, 6]
# [1546, 36, 141, 81, 2342, 1604, 6]
# [16, 47, 485, 357, 89, 46, 1227, 6]
# [37, 30, 2257, 35, 59, 6]
# [16, 117, 293, 6]
# [97, 26, 241, 56, 371, 491, 6]
# [36, 346, 861, 846, 471, 36, 30, 689, 970, 6]
# [34, 529, 72, 66, 503, 1837, 1134, 726, 6]
# [20, 634, 337, 1647, 503, 2474, 291, 48, 100, 40, 83, 597, 6]
# [39, 26, 64, 854, 6]
# [3017, 131, 1091, 35, 1660, 6]
# [97, 26, 681, 61, 6]
# [39, 55, 381, 76, 431, 6]
# [8, 98, 211, 38, 8, 1027, 49, 1453, 6]
# [52, 87, 74, 43, 131, 418, 7]
# [37, 75, 8, 2699, 17, 1156, 6]
# [37, 502, 61, 8, 26, 2938, 2114, 41, 36, 1575, 6]
# [37, 203, 35, 387, 34, 6]
# [45, 38, 1988, 6]
# [51, 397, 8, 386, 9, 646, 2038, 66, 236, 106, 78, 6]
# [36, 691, 8, 1789, 1893, 44, 106, 46, 312, 6]
# [37, 205, 59, 26, 899, 6]
# [9, 1837, 1647, 2472, 66, 443, 258, 60, 153, 6]
# [16, 20, 145, 577, 49, 45, 6]
# [39, 205, 8, 286, 111, 63, 545, 6]
# [47, 34, 260, 423, 26, 2593, 2480, 407, 11, 2275, 7]
# [16, 85, 27, 219, 63, 107, 6]
# [80, 89, 1695, 125, 8, 586, 49, 2336, 7]
# [94, 119, 44, 80, 35, 90, 35, 36, 882, 6]
# [8, 973, 27, 2932, 1950, 1391, 2481, 38, 1408, 6]
# [80, 38, 36, 41, 2483, 337, 3123, 782, 26, 107, 7]
# [209, 147, 696, 6]
# [46, 698, 48, 1243, 67, 1540, 6]
# [176, 16, 151, 45, 496, 7]

# %%
# Lookup each token id in the vocabulary.
txt_tokens = tf.gather(en_vocab, token_batch)
# Join with spaces.
tf.strings.reduce_join(txt_tokens, separator=' ', axis=-1)
# Out:
# <tf.Tensor: shape=(100,), dtype=string, numpy=
# array([b'who does that belong to ?', b'warn tom .',
#        b'i just wanted to see you .',
#        b'the plans were d ##is ##c ##ard ##ed .',
#        b'all the students come from the us .',
#        b'since i was sick , i didn t go .', b'you have my word .',
#        b'my husband always reads in bed .',
#        b'all the students were there .',
#        b'my heart was filled with happiness .',
#        b'no one speaks this language anymore .',
#        b'i walk in the forest every day .',
#        b'you don t need to work today .', b'i know it s an experiment .',
#        b'we want our money .', b'this room doesn t get much sun .',
#        b'no one will believe you .', b'i m not telling you .',
#        b'that s what you all say .', b'i have a bad pain in my back .',
#        b'i have a special surprise for you .', b'i screamed .',
#        b'tell me what you want for christmas .',
#        b'half of these are mine .', b'we re in love .',
#        b'it is wrong to steal money .', b'no one knows why .',
#        b'i recommend m ##a ##u ##i .',
#        b'thanks for your c ##oo ##per ##ation .',
#        b'just do what i tell you .',
#        b'his s ##m ##ug behavior is off ##ens ##ive .',
#        b'don t point your gun at me .', b'tom hugged mary tight ##ly .',
#        b'he likes singing and dancing .', b'i need my pills .',
#        b'we watch tv together .', b'is it there ?',
#        b'i can keep a secret .', b'i ve always wanted to meet you .',
#        b'look ! there s a bird in that tree .',
#        b'the engine is p ##ur ##ring .',
#        b'i just can t forget about you .',
#        b'i could just refuse to help tom .', b'tom liked australia .',
#        b'tom can t think of a better plan .',
#        b'tom wanted to stop and think .', b'nobody does that anymore .',
#        b'even tom was baffled .',
#        b'the air condition ##er is out of order .', b'look at that dog .',
#        b'have you seen my camera ?',
#        b'tom closed the door and locked it .',
#        b'i tried to persuade tom to come home .',
#        b'tom walked across the street .', b'who teaches you french ?',
#        b'we re feeling confident .', b'do come in !',
#        b'this is delicious .', b'tom can t play tennis .',
#        b'do you know anything about tom ?',
#        b'tom seems in ##co ##m ##pet ##ent .',
#        b'i hope you aren t alone .',
#        b'the problem is difficult to solve .',
#        b'tom doesn t trust a thing mary says .',
#        b'can you play the violin ?', b'he gave in .',
#        b'he cut down a c ##her ##ry tree .',
#        b'perhaps the book will prove useful .',
#        b'i have trouble talking about my feelings .',
#        b'tom w ##aved to mary .', b'i never drink .',
#        b'let s wait for another minutes .',
#        b'the early bird catch ##es the w ##or ##m .',
#        b'you seem re ##s ##o ##ur ##ce ##ful .',
#        b'm ##on ##t ##g ##o ##mer ##y was where it all began .',
#        b'he s not perfect .', b'jeans take forever to dry .',
#        b'let s move on .', b'he can swim very fast .',
#        b'a no ##d is a sign of agreement .',
#        b'what time did that take place ?', b'tom has a private j ##et .',
#        b'tom sat on a s ##to ##ol in the corner .',
#        b'tom wanted to meet you .', b'this is hers .',
#        b'she lives a few b ##l ##ock ##s away from here .',
#        b'the noise a ##w ##oke me from my sleep .',
#        b'tom wants mary s opinion .',
#        b'b ##ur ##g ##lar ##s broke into his house .',
#        b'i m really proud of this .',
#        b'he wants a watch just like yours .',
#        b'have you ever tried s ##c ##ub ##a d ##iving ?',
#        b'i didn t feel like going .',
#        b'how about add ##ing a touch of pepper ?',
#        b'please tell me how to get to the beach .',
#        b'a blood t ##ra ##ns ##f ##usion is necessary .',
#        b'how is the in ##ves ##t ##ig ##ation s going ?',
#        b'everything went black .',
#        b'my heart was filled with happiness .', b'may i eat this cake ?'],
#       dtype=object)>

# %%
words = en_tokenizer.detokenize(token_batch)
tf.strings.reduce_join(words, separator=' ', axis=-1)
# Out:
# <tf.Tensor: shape=(100,), dtype=string, numpy=
# array([b'who does that belong to ?', b'warn tom .',
#        b'i just wanted to see you .', b'the plans were discarded .',
#        b'all the students come from the us .',
#        b'since i was sick , i didn t go .', b'you have my word .',
#        b'my husband always reads in bed .',
#        b'all the students were there .',
#        b'my heart was filled with happiness .',
#        b'no one speaks this language anymore .',
#        b'i walk in the forest every day .',
#        b'you don t need to work today .', b'i know it s an experiment .',
#        b'we want our money .', b'this room doesn t get much sun .',
#        b'no one will believe you .', b'i m not telling you .',
#        b'that s what you all say .', b'i have a bad pain in my back .',
#        b'i have a special surprise for you .', b'i screamed .',
#        b'tell me what you want for christmas .',
#        b'half of these are mine .', b'we re in love .',
#        b'it is wrong to steal money .', b'no one knows why .',
#        b'i recommend maui .', b'thanks for your cooperation .',
#        b'just do what i tell you .', b'his smug behavior is offensive .',
#        b'don t point your gun at me .', b'tom hugged mary tightly .',
#        b'he likes singing and dancing .', b'i need my pills .',
#        b'we watch tv together .', b'is it there ?',
#        b'i can keep a secret .', b'i ve always wanted to meet you .',
#        b'look ! there s a bird in that tree .',
#        b'the engine is purring .', b'i just can t forget about you .',
#        b'i could just refuse to help tom .', b'tom liked australia .',
#        b'tom can t think of a better plan .',
#        b'tom wanted to stop and think .', b'nobody does that anymore .',
#        b'even tom was baffled .',
#        b'the air conditioner is out of order .', b'look at that dog .',
#        b'have you seen my camera ?',
#        b'tom closed the door and locked it .',
#        b'i tried to persuade tom to come home .',
#        b'tom walked across the street .', b'who teaches you french ?',
#        b'we re feeling confident .', b'do come in !',
#        b'this is delicious .', b'tom can t play tennis .',
#        b'do you know anything about tom ?', b'tom seems incompetent .',
#        b'i hope you aren t alone .',
#        b'the problem is difficult to solve .',
#        b'tom doesn t trust a thing mary says .',
#        b'can you play the violin ?', b'he gave in .',
#        b'he cut down a cherry tree .',
#        b'perhaps the book will prove useful .',
#        b'i have trouble talking about my feelings .',
#        b'tom waved to mary .', b'i never drink .',
#        b'let s wait for another minutes .',
#        b'the early bird catches the worm .', b'you seem resourceful .',
#        b'montgomery was where it all began .', b'he s not perfect .',
#        b'jeans take forever to dry .', b'let s move on .',
#        b'he can swim very fast .', b'a nod is a sign of agreement .',
#        b'what time did that take place ?', b'tom has a private jet .',
#        b'tom sat on a stool in the corner .', b'tom wanted to meet you .',
#        b'this is hers .', b'she lives a few blocks away from here .',
#        b'the noise awoke me from my sleep .',
#        b'tom wants mary s opinion .', b'burglars broke into his house .',
#        b'i m really proud of this .',
#        b'he wants a watch just like yours .',
#        b'have you ever tried scuba diving ?',
#        b'i didn t feel like going .',
#        b'how about adding a touch of pepper ?',
#        b'please tell me how to get to the beach .',
#        b'a blood transfusion is necessary .',
#        b'how is the investigation s going ?', b'everything went black .',
#        b'my heart was filled with happiness .', b'may i eat this cake ?'],
#       dtype=object)>

# %% [markdown]
# CUSTOMIZATION AND EXPORTTTT

# %%
START = tf.argmax(tf.constant(reserved_tokens) == "[START]")
END = tf.argmax(tf.constant(reserved_tokens) == "[END]")

def add_start_end(ragged):
  count = ragged.bounding_shape()[0]
  starts = tf.fill([count,1], START)
  ends = tf.fill([count,1], END)
  return tf.concat([starts, ragged, ends], axis=1)

# %%
words = en_tokenizer.detokenize(add_start_end(token_batch))
tf.strings.reduce_join(words, separator=' ', axis=-1)
# Out:
# <tf.Tensor: shape=(100,), dtype=string, numpy=
# array([b'[START] who does that belong to ? [END]',
#        b'[START] warn tom . [END]',
#        b'[START] i just wanted to see you . [END]',
#        b'[START] the plans were discarded . [END]',
#        b'[START] all the students come from the us . [END]',
#        b'[START] since i was sick , i didn t go . [END]',
#        b'[START] you have my word . [END]',
#        b'[START] my husband always reads in bed . [END]',
#        b'[START] all the students were there . [END]',
#        b'[START] my heart was filled with happiness . [END]',
#        b'[START] no one speaks this language anymore . [END]',
#        b'[START] i walk in the forest every day . [END]',
#        b'[START] you don t need to work today . [END]',
#        b'[START] i know it s an experiment . [END]',
#        b'[START] we want our money . [END]',
#        b'[START] this room doesn t get much sun . [END]',
#        b'[START] no one will believe you . [END]',
#        b'[START] i m not telling you . [END]',
#        b'[START] that s what you all say . [END]',
#        b'[START] i have a bad pain in my back . [END]',
#        b'[START] i have a special surprise for you . [END]',
#        b'[START] i screamed . [END]',
#        b'[START] tell me what you want for christmas . [END]',
#        b'[START] half of these are mine . [END]',
#        b'[START] we re in love . [END]',
#        b'[START] it is wrong to steal money . [END]',
#        b'[START] no one knows why . [END]',
#        b'[START] i recommend maui . [END]',
#        b'[START] thanks for your cooperation . [END]',
#        b'[START] just do what i tell you . [END]',
#        b'[START] his smug behavior is offensive . [END]',
#        b'[START] don t point your gun at me . [END]',
#        b'[START] tom hugged mary tightly . [END]',
#        b'[START] he likes singing and dancing . [END]',
#        b'[START] i need my pills . [END]',
#        b'[START] we watch tv together . [END]',
#        b'[START] is it there ? [END]',
#        b'[START] i can keep a secret . [END]',
#        b'[START] i ve always wanted to meet you . [END]',
#        b'[START] look ! there s a bird in that tree . [END]',
#        b'[START] the engine is purring . [END]',
#        b'[START] i just can t forget about you . [END]',
#        b'[START] i could just refuse to help tom . [END]',
#        b'[START] tom liked australia . [END]',
#        b'[START] tom can t think of a better plan . [END]',
#        b'[START] tom wanted to stop and think . [END]',
#        b'[START] nobody does that anymore . [END]',
#        b'[START] even tom was baffled . [END]',
#        b'[START] the air conditioner is out of order . [END]',
#        b'[START] look at that dog . [END]',
#        b'[START] have you seen my camera ? [END]',
#        b'[START] tom closed the door and locked it . [END]',
#        b'[START] i tried to persuade tom to come home . [END]',
#        b'[START] tom walked across the street . [END]',
#        b'[START] who teaches you french ? [END]',
#        b'[START] we re feeling confident . [END]',
#        b'[START] do come in ! [END]',
#        b'[START] this is delicious . [END]',
#        b'[START] tom can t play tennis . [END]',
#        b'[START] do you know anything about tom ? [END]',
#        b'[START] tom seems incompetent . [END]',
#        b'[START] i hope you aren t alone . [END]',
#        b'[START] the problem is difficult to solve . [END]',
#        b'[START] tom doesn t trust a thing mary says . [END]',
#        b'[START] can you play the violin ? [END]',
#        b'[START] he gave in . [END]',
#        b'[START] he cut down a cherry tree . [END]',
#        b'[START] perhaps the book will prove useful . [END]',
#        b'[START] i have trouble talking about my feelings . [END]',
#        b'[START] tom waved to mary . [END]',
#        b'[START] i never drink . [END]',
#        b'[START] let s wait for another minutes . [END]',
#        b'[START] the early bird catches the worm . [END]',
#        b'[START] you seem resourceful . [END]',
#        b'[START] montgomery was where it all began . [END]',
#        b'[START] he s not perfect . [END]',
#        b'[START] jeans take forever to dry . [END]',
#        b'[START] let s move on . [END]',
#        b'[START] he can swim very fast . [END]',
#        b'[START] a nod is a sign of agreement . [END]',
#        b'[START] what time did that take place ? [END]',
#        b'[START] tom has a private jet . [END]',
#        b'[START] tom sat on a stool in the corner . [END]',
#        b'[START] tom wanted to meet you . [END]',
#        b'[START] this is hers . [END]',
#        b'[START] she lives a few blocks away from here . [END]',
#        b'[START] the noise awoke me from my sleep . [END]',
#        b'[START] tom wants mary s opinion . [END]',
#        b'[START] burglars broke into his house . [END]',
#        b'[START] i m really proud of this . [END]',
#        b'[START] he wants a watch just like yours . [END]',
#        b'[START] have you ever tried scuba diving ? [END]',
#        b'[START] i didn t feel like going . [END]',
#        b'[START] how about adding a touch of pepper ? [END]',
#        b'[START] please tell me how to get to the beach . [END]',
#        b'[START] a blood transfusion is necessary . [END]',
#        b'[START] how is the investigation s going ? [END]',
#        b'[START] everything went black . [END]',
#        b'[START] my heart was filled with happiness . [END]',
#        b'[START] may i eat this cake ? [END]'], dtype=object)>

# %%
# detokenization
def cleanup_text(reserved_tokens, token_txt):
  # drop reserved tokens except for [UNK]
  bad_tokens = [re.escape(tok) for tok in reserved_tokens if tok != "[UNK]"]
  bad_token_re = "|".join(bad_tokens)

  bad_cells = tf.strings.regex_full_match(token_txt, bad_token_re)
  result = tf.ragged.boolean_mask(token_txt, ~bad_cells)

  # Join them into strings
  result = tf.strings.reduce_join(result, separator=' ', axis=-1)
  return result

# %%
en_examples.numpy()
# Out:
# array([b'who does that belong to ?', b'warn tom .',
#        b'i just wanted to see you .', b'the plans were discarded .',
#        b'all the students come from the us .',
#        b'since i was sick , i didn t go .', b'you have my word .',
#        b'my husband always reads in bed .',
#        b'all the students were there .',
#        b'my heart was filled with happiness .',
#        b'no one speaks this language anymore .',
#        b'i walk in the forest every day .',
#        b'you don t need to work today .', b'i know it s an experiment .',
#        b'we want our money .', b'this room doesn t get much sun .',
#        b'no one will believe you .', b'i m not telling you .',
#        b'that s what you all say .', b'i have a bad pain in my back .',
#        b'i have a special surprise for you .', b'i screamed .',
#        b'tell me what you want for christmas .',
#        b'half of these are mine .', b'we re in love .',
#        b'it is wrong to steal money .', b'no one knows why .',
#        b'i recommend maui .', b'thanks for your cooperation .',
#        b'just do what i tell you .', b'his smug behavior is offensive .',
#        b'don t point your gun at me .', b'tom hugged mary tightly .',
#        b'he likes singing and dancing .', b'i need my pills .',
#        b'we watch tv together .', b'is it there ?',
#        b'i can keep a secret .', b'i ve always wanted to meet you .',
#        b'look ! there s a bird in that tree .',
#        b'the engine is purring .', b'i just can t forget about you .',
#        b'i could just refuse to help tom .', b'tom liked australia .',
#        b'tom can t think of a better plan .',
#        b'tom wanted to stop and think .', b'nobody does that anymore .',
#        b'even tom was baffled .',
#        b'the air conditioner is out of order .', b'look at that dog .',
#        b'have you seen my camera ?',
#        b'tom closed the door and locked it .',
#        b'i tried to persuade tom to come home .',
#        b'tom walked across the street .', b'who teaches you french ?',
#        b'we re feeling confident .', b'do come in !',
#        b'this is delicious .', b'tom can t play tennis .',
#        b'do you know anything about tom ?', b'tom seems incompetent .',
#        b'i hope you aren t alone .',
#        b'the problem is difficult to solve .',
#        b'tom doesn t trust a thing mary says .',
#        b'can you play the violin ?', b'he gave in .',
#        b'he cut down a cherry tree .',
#        b'perhaps the book will prove useful .',
#        b'i have trouble talking about my feelings .',
#        b'tom waved to mary .', b'i never drink .',
#        b'let s wait for another minutes .',
#        b'the early bird catches the worm .', b'you seem resourceful .',
#        b'montgomery was where it all began .', b'he s not perfect .',
#        b'jeans take forever to dry .', b'let s move on .',
#        b'he can swim very fast .', b'a nod is a sign of agreement .',
#        b'what time did that take place ?', b'tom has a private jet .',
#        b'tom sat on a stool in the corner .', b'tom wanted to meet you .',
#        b'this is hers .', b'she lives a few blocks away from here .',
#        b'the noise awoke me from my sleep .',
#        b'tom wants mary s opinion .', b'burglars broke into his house .',
#        b'i m really proud of this .',
#        b'he wants a watch just like yours .',
#        b'have you ever tried scuba diving ?',
#        b'i didn t feel like going .',
#        b'how about adding a touch of pepper ?',
#        b'please tell me how to get to the beach .',
#        b'a blood transfusion is necessary .',
#        b'how is the investigation s going ?', b'everything went black .',
#        b'my heart was filled with happiness .', b'may i eat this cake ?'],
#       dtype=object)

# %%
token_batch = en_tokenizer.tokenize(en_examples).merge_dims(-2, -1)
words = en_tokenizer.detokenize(token_batch)
words
# Out:
# <tf.RaggedTensor [[b'who', b'does', b'that', b'belong', b'to', b'?'],
#  [b'warn', b'tom', b'.'],
#  [b'i', b'just', b'wanted', b'to', b'see', b'you', b'.'],
#  [b'the', b'plans', b'were', b'discarded', b'.'],
#  [b'all', b'the', b'students', b'come', b'from', b'the', b'us', b'.'],
#  [b'since', b'i', b'was', b'sick', b',', b'i', b'didn', b't', b'go', b'.'],
#  [b'you', b'have', b'my', b'word', b'.'],
#  [b'my', b'husband', b'always', b'reads', b'in', b'bed', b'.'],
#  [b'all', b'the', b'students', b'were', b'there', b'.'],
#  [b'my', b'heart', b'was', b'filled', b'with', b'happiness', b'.'],
#  [b'no', b'one', b'speaks', b'this', b'language', b'anymore', b'.'],
#  [b'i', b'walk', b'in', b'the', b'forest', b'every', b'day', b'.'],
#  [b'you', b'don', b't', b'need', b'to', b'work', b'today', b'.'],
#  [b'i', b'know', b'it', b's', b'an', b'experiment', b'.'],
#  [b'we', b'want', b'our', b'money', b'.'],
#  [b'this', b'room', b'doesn', b't', b'get', b'much', b'sun', b'.'],
#  [b'no', b'one', b'will', b'believe', b'you', b'.'],
#  [b'i', b'm', b'not', b'telling', b'you', b'.'],
#  [b'that', b's', b'what', b'you', b'all', b'say', b'.'],
#  [b'i', b'have', b'a', b'bad', b'pain', b'in', b'my', b'back', b'.'],
#  [b'i', b'have', b'a', b'special', b'surprise', b'for', b'you', b'.'],
#  [b'i', b'screamed', b'.'],
#  [b'tell', b'me', b'what', b'you', b'want', b'for', b'christmas', b'.'],
#  [b'half', b'of', b'these', b'are', b'mine', b'.'],
#  [b'we', b're', b'in', b'love', b'.'],
#  [b'it', b'is', b'wrong', b'to', b'steal', b'money', b'.'],
#  [b'no', b'one', b'knows', b'why', b'.'],
#  [b'i', b'recommend', b'maui', b'.'],
#  [b'thanks', b'for', b'your', b'cooperation', b'.'],
#  [b'just', b'do', b'what', b'i', b'tell', b'you', b'.'],
#  [b'his', b'smug', b'behavior', b'is', b'offensive', b'.'],
#  [b'don', b't', b'point', b'your', b'gun', b'at', b'me', b'.'],
#  [b'tom', b'hugged', b'mary', b'tightly', b'.'],
#  [b'he', b'likes', b'singing', b'and', b'dancing', b'.'],
#  [b'i', b'need', b'my', b'pills', b'.'],
#  [b'we', b'watch', b'tv', b'together', b'.'],
#  [b'is', b'it', b'there', b'?'],
#  [b'i', b'can', b'keep', b'a', b'secret', b'.'],
#  [b'i', b've', b'always', b'wanted', b'to', b'meet', b'you', b'.'],
#  [b'look', b'!', b'there', b's', b'a', b'bird', b'in', b'that', b'tree',
#   b'.']                                                                 ,
#  [b'the', b'engine', b'is', b'purring', b'.'],
#  [b'i', b'just', b'can', b't', b'forget', b'about', b'you', b'.'],
#  [b'i', b'could', b'just', b'refuse', b'to', b'help', b'tom', b'.'],
#  [b'tom', b'liked', b'australia', b'.'],
#  [b'tom', b'can', b't', b'think', b'of', b'a', b'better', b'plan', b'.'],
#  [b'tom', b'wanted', b'to', b'stop', b'and', b'think', b'.'],
#  [b'nobody', b'does', b'that', b'anymore', b'.'],
#  [b'even', b'tom', b'was', b'baffled', b'.'],
#  [b'the', b'air', b'conditioner', b'is', b'out', b'of', b'order', b'.'],
#  [b'look', b'at', b'that', b'dog', b'.'],
#  [b'have', b'you', b'seen', b'my', b'camera', b'?'],
#  [b'tom', b'closed', b'the', b'door', b'and', b'locked', b'it', b'.'],
#  [b'i', b'tried', b'to', b'persuade', b'tom', b'to', b'come', b'home', b'.'],
#  [b'tom', b'walked', b'across', b'the', b'street', b'.'],
#  [b'who', b'teaches', b'you', b'french', b'?'],
#  [b'we', b're', b'feeling', b'confident', b'.'],
#  [b'do', b'come', b'in', b'!'], [b'this', b'is', b'delicious', b'.'],
#  [b'tom', b'can', b't', b'play', b'tennis', b'.'],
#  [b'do', b'you', b'know', b'anything', b'about', b'tom', b'?'],
#  [b'tom', b'seems', b'incompetent', b'.'],
#  [b'i', b'hope', b'you', b'aren', b't', b'alone', b'.'],
#  [b'the', b'problem', b'is', b'difficult', b'to', b'solve', b'.'],
#  [b'tom', b'doesn', b't', b'trust', b'a', b'thing', b'mary', b'says', b'.'],
#  [b'can', b'you', b'play', b'the', b'violin', b'?'],
#  [b'he', b'gave', b'in', b'.'],
#  [b'he', b'cut', b'down', b'a', b'cherry', b'tree', b'.'],
#  [b'perhaps', b'the', b'book', b'will', b'prove', b'useful', b'.'],
#  [b'i', b'have', b'trouble', b'talking', b'about', b'my', b'feelings', b'.'],
#  [b'tom', b'waved', b'to', b'mary', b'.'],
#  [b'i', b'never', b'drink', b'.'],
#  [b'let', b's', b'wait', b'for', b'another', b'minutes', b'.'],
#  [b'the', b'early', b'bird', b'catches', b'the', b'worm', b'.'],
#  [b'you', b'seem', b'resourceful', b'.'],
#  [b'montgomery', b'was', b'where', b'it', b'all', b'began', b'.'],
#  [b'he', b's', b'not', b'perfect', b'.'],
#  [b'jeans', b'take', b'forever', b'to', b'dry', b'.'],
#  [b'let', b's', b'move', b'on', b'.'],
#  [b'he', b'can', b'swim', b'very', b'fast', b'.'],
#  [b'a', b'nod', b'is', b'a', b'sign', b'of', b'agreement', b'.'],
#  [b'what', b'time', b'did', b'that', b'take', b'place', b'?'],
#  [b'tom', b'has', b'a', b'private', b'jet', b'.'],
#  [b'tom', b'sat', b'on', b'a', b'stool', b'in', b'the', b'corner', b'.'],
#  [b'tom', b'wanted', b'to', b'meet', b'you', b'.'],
#  [b'this', b'is', b'hers', b'.'],
#  [b'she', b'lives', b'a', b'few', b'blocks', b'away', b'from', b'here',
#   b'.']                                                                ,
#  [b'the', b'noise', b'awoke', b'me', b'from', b'my', b'sleep', b'.'],
#  [b'tom', b'wants', b'mary', b's', b'opinion', b'.'],
#  [b'burglars', b'broke', b'into', b'his', b'house', b'.'],
#  [b'i', b'm', b'really', b'proud', b'of', b'this', b'.'],
#  [b'he', b'wants', b'a', b'watch', b'just', b'like', b'yours', b'.'],
#  [b'have', b'you', b'ever', b'tried', b'scuba', b'diving', b'?'],
#  [b'i', b'didn', b't', b'feel', b'like', b'going', b'.'],
#  [b'how', b'about', b'adding', b'a', b'touch', b'of', b'pepper', b'?'],
#  [b'please', b'tell', b'me', b'how', b'to', b'get', b'to', b'the', b'beach',
#   b'.']                                                                     ,
#  [b'a', b'blood', b'transfusion', b'is', b'necessary', b'.'],
#  [b'how', b'is', b'the', b'investigation', b's', b'going', b'?'],
#  [b'everything', b'went', b'black', b'.'],
#  [b'my', b'heart', b'was', b'filled', b'with', b'happiness', b'.'],
#  [b'may', b'i', b'eat', b'this', b'cake', b'?']]>

# %%
cleanup_text(reserved_tokens, words).numpy()
# Out:
# array([b'who does that belong to ?', b'warn tom .',
#        b'i just wanted to see you .', b'the plans were discarded .',
#        b'all the students come from the us .',
#        b'since i was sick , i didn t go .', b'you have my word .',
#        b'my husband always reads in bed .',
#        b'all the students were there .',
#        b'my heart was filled with happiness .',
#        b'no one speaks this language anymore .',
#        b'i walk in the forest every day .',
#        b'you don t need to work today .', b'i know it s an experiment .',
#        b'we want our money .', b'this room doesn t get much sun .',
#        b'no one will believe you .', b'i m not telling you .',
#        b'that s what you all say .', b'i have a bad pain in my back .',
#        b'i have a special surprise for you .', b'i screamed .',
#        b'tell me what you want for christmas .',
#        b'half of these are mine .', b'we re in love .',
#        b'it is wrong to steal money .', b'no one knows why .',
#        b'i recommend maui .', b'thanks for your cooperation .',
#        b'just do what i tell you .', b'his smug behavior is offensive .',
#        b'don t point your gun at me .', b'tom hugged mary tightly .',
#        b'he likes singing and dancing .', b'i need my pills .',
#        b'we watch tv together .', b'is it there ?',
#        b'i can keep a secret .', b'i ve always wanted to meet you .',
#        b'look ! there s a bird in that tree .',
#        b'the engine is purring .', b'i just can t forget about you .',
#        b'i could just refuse to help tom .', b'tom liked australia .',
#        b'tom can t think of a better plan .',
#        b'tom wanted to stop and think .', b'nobody does that anymore .',
#        b'even tom was baffled .',
#        b'the air conditioner is out of order .', b'look at that dog .',
#        b'have you seen my camera ?',
#        b'tom closed the door and locked it .',
#        b'i tried to persuade tom to come home .',
#        b'tom walked across the street .', b'who teaches you french ?',
#        b'we re feeling confident .', b'do come in !',
#        b'this is delicious .', b'tom can t play tennis .',
#        b'do you know anything about tom ?', b'tom seems incompetent .',
#        b'i hope you aren t alone .',
#        b'the problem is difficult to solve .',
#        b'tom doesn t trust a thing mary says .',
#        b'can you play the violin ?', b'he gave in .',
#        b'he cut down a cherry tree .',
#        b'perhaps the book will prove useful .',
#        b'i have trouble talking about my feelings .',
#        b'tom waved to mary .', b'i never drink .',
#        b'let s wait for another minutes .',
#        b'the early bird catches the worm .', b'you seem resourceful .',
#        b'montgomery was where it all began .', b'he s not perfect .',
#        b'jeans take forever to dry .', b'let s move on .',
#        b'he can swim very fast .', b'a nod is a sign of agreement .',
#        b'what time did that take place ?', b'tom has a private jet .',
#        b'tom sat on a stool in the corner .', b'tom wanted to meet you .',
#        b'this is hers .', b'she lives a few blocks away from here .',
#        b'the noise awoke me from my sleep .',
#        b'tom wants mary s opinion .', b'burglars broke into his house .',
#        b'i m really proud of this .',
#        b'he wants a watch just like yours .',
#        b'have you ever tried scuba diving ?',
#        b'i didn t feel like going .',
#        b'how about adding a touch of pepper ?',
#        b'please tell me how to get to the beach .',
#        b'a blood transfusion is necessary .',
#        b'how is the investigation s going ?', b'everything went black .',
#        b'my heart was filled with happiness .', b'may i eat this cake ?'],
#       dtype=object)

# %%
class CustomTokenizer(tf.Module):
  def __init__(self, reserved_tokens, vocab_path):
    self.tokenizer = text.BertTokenizer(vocab_path, lower_case=True)
    self._reserved_tokens = reserved_tokens
    self._vocab_path = tf.saved_model.Asset(vocab_path)

    vocab = pathlib.Path(vocab_path).read_text().splitlines()
    self.vocab = tf.Variable(vocab)

    ## Create the signatures for export:

    # Include a tokenize signature for a batch of strings.
    self.tokenize.get_concrete_function(
        tf.TensorSpec(shape=[None], dtype=tf.string))

    # Include `detokenize` and `lookup` signatures for:
    #   * `Tensors` with shapes [tokens] and [batch, tokens]
    #   * `RaggedTensors` with shape [batch, tokens]
    self.detokenize.get_concrete_function(
        tf.TensorSpec(shape=[None, None], dtype=tf.int64))
    self.detokenize.get_concrete_function(
          tf.RaggedTensorSpec(shape=[None, None], dtype=tf.int64))

    self.lookup.get_concrete_function(
        tf.TensorSpec(shape=[None, None], dtype=tf.int64))
    self.lookup.get_concrete_function(
          tf.RaggedTensorSpec(shape=[None, None], dtype=tf.int64))

    # These `get_*` methods take no arguments
    self.get_vocab_size.get_concrete_function()
    self.get_vocab_path.get_concrete_function()
    self.get_reserved_tokens.get_concrete_function()

  @tf.function
  def tokenize(self, strings):
    enc = self.tokenizer.tokenize(strings)
    # Merge the `word` and `word-piece` axes.
    enc = enc.merge_dims(-2,-1)
    enc = add_start_end(enc)
    return enc

  @tf.function
  def detokenize(self, tokenized):
    words = self.tokenizer.detokenize(tokenized)
    return cleanup_text(self._reserved_tokens, words)

  @tf.function
  def lookup(self, token_ids):
    return tf.gather(self.vocab, token_ids)

  @tf.function
  def get_vocab_size(self):
    return tf.shape(self.vocab)[0]

  @tf.function
  def get_vocab_path(self):
    return self._vocab_path

  @tf.function
  def get_reserved_tokens(self):
    return tf.constant(self._reserved_tokens)

# %%
# buiild tokenizer for eazh language

tokenizers = tf.Module()
tokenizers.en = CustomTokenizer(reserved_tokens, 'en_vocab.txt')
tokenizers.sp = CustomTokenizer(reserved_tokens, 'sp_vocab.txt')

# %%
# export as a saved_model
model_name = 'sp_en_converter'
tf.saved_model.save(tokenizers, model_name)

# %%
reloaded_tokenizers = tf.saved_model.load(model_name)
reloaded_tokenizers.en.get_vocab_size().numpy()
# Out:
# np.int32(3333)

# %%
tokens = reloaded_tokenizers.en.tokenize(['Hello TensorFlow!'])
tokens.numpy()
# Out:
# array([[   2, 1581,  377,   66,  689, 1391, 2279,    4,    3]])

# %%
text_tokens = reloaded_tokenizers.en.lookup(tokens)
text_tokens
# Out:
# <tf.RaggedTensor [[b'[START]', b'hello', b'ten', b'##s', b'##or', b'##f', b'##low', b'!',
#   b'[END]']]>

# %%
round_trip = reloaded_tokenizers.en.detokenize(tokens)

print(round_trip.numpy()[0].decode('utf-8'))
# Out:
# hello tensorflow !

# %%
# !zip -r {model_name}.zip {model_name}
# Out:
#   adding: sp_en_converter/ (stored 0%)
#   adding: sp_en_converter/fingerprint.pb (stored 0%)
#   adding: sp_en_converter/saved_model.pb (deflated 91%)
#   adding: sp_en_converter/assets/ (stored 0%)
#   adding: sp_en_converter/assets/sp_vocab.txt (deflated 56%)
#   adding: sp_en_converter/assets/en_vocab.txt (deflated 52%)
#   adding: sp_en_converter/variables/ (stored 0%)
#   adding: sp_en_converter/variables/variables.data-00000-of-00001 (deflated 50%)
#   adding: sp_en_converter/variables/variables.index (deflated 33%)

# %%
# !du -h *.zip
# Out:
# 120K	sp_en_converter.zip

# %%
# !path model_name
# Out:
# /bin/bash: line 1: path: command not found
